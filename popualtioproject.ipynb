# %%
# !conda install -c anaconda seaborn -y
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/Nico/opt/anaconda3
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.10.14 |                0         127 KB  anaconda
#     openssl-1.1.1h             |       haf1e3a3_0         3.4 MB  anaconda
#     seaborn-0.11.0             |             py_0         216 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         3.8 MB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates                                 pkgs/main --> anaconda
#   openssl                                         pkgs/main --> anaconda
#   seaborn                                         pkgs/main --> anaconda
#
#
#
# ...

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Load in dataset
populations = pd.read_csv('population_by_country_2020.csv')

# %%
# Made our DataFrame
df = pd.DataFrame(populations)

# %%
# Explore the dataset
df.head(10)
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1438207241        0.39 %     5540090
# 1                   India         1377233523        0.99 %    13586631
# 2           United States          330610570        0.59 %     1937734
# 3               Indonesia          272931713        1.07 %     2898047
# 4                Pakistan          219992900        2.00 %     4327022
# 5                  Brazil          212253150        0.72 %     1509890
# 6                 Nigeria          205052107        2.58 %     5175990
# 7              Bangladesh          164354176        1.01 %     1643222
# 8                  Russia          145922010        0.04 %       62206
# 9                  Mexico          128655589        1.06 %     1357224
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# ...

# %%
#Fill in all the N.A entries with 0.
df.replace(np.nan,0)
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                     China         1438207241        0.39 %     5540090
# 1                     India         1377233523        0.99 %    13586631
# 2             United States          330610570        0.59 %     1937734
# 3                 Indonesia          272931713        1.07 %     2898047
# 4                  Pakistan          219992900        2.00 %     4327022
# ..                      ...                ...           ...         ...
# 230              Montserrat               4991        0.06 %           3
# 231        Falkland Islands               3458        3.05 %         103
# 232                    Niue               1624        0.68 %          11
# 233                 Tokelau               1354        1.27 %          17
# 234                Holy See                801        0.25 %           2
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# ...

# %%
df
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                     China         1438207241        0.39 %     5540090
# 1                     India         1377233523        0.99 %    13586631
# 2             United States          330610570        0.59 %     1937734
# 3                 Indonesia          272931713        1.07 %     2898047
# 4                  Pakistan          219992900        2.00 %     4327022
# ..                      ...                ...           ...         ...
# 230              Montserrat               4991        0.06 %           3
# 231        Falkland Islands               3458        3.05 %         103
# 232                    Niue               1624        0.68 %          11
# 233                 Tokelau               1354        1.27 %          17
# 234                Holy See                801        0.25 %           2
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# ...

# %%
# Select the Classifier
from sklearn.linear_model import LinearRegression

# %%
#Select the Model 
from sklearn.model_selection import train_test_split

# %%
# Features we're starting off with since other features contain NaN
x = df[['Land Area (Km²)', 'Density (P/Km²)']]

# %%
# Target
y = df[['Population (2020)']]

# %%
# TTS lets us split our data into easily processed chunks
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2, random_state=6)

# %%
#Fit the model
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
print("MAE: {}".format(np.abs(y_test-y_pred).mean()))
print("RMSE: {}".format(np.sqrt(((y_test-y_pred)**2).mean())))
# Out:
# MAE: Population (2020)    3.699286e+07
# dtype: float64
# RMSE: Population (2020)    8.327127e+07
# dtype: float64

# %%
#Plotting the figure
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(1, figsize=(6, 4))
plt.clf()

elev = 43.5
azim = -110

ax = Axes3D(fig, elev=elev, azim=azim)


ax.set_xlabel('Land Area (Km²)')
ax.set_ylabel('Density (P/Km²)')
ax.set_zlabel('Population')

#Scatter Plot
ax.scatter(x_train[['Land Area (Km²)']], x_train[['Density (P/Km²)']], y_train, c='k', marker='+')
ax.plot_surface(np.array([[0, 0], [16376870, 16376870]]), np.array([[0, 26337], [0, 26337]]), model.predict(np.array([[0, 0, 16376870, 16376870], [0, 26337, 0, 26337]]).T).reshape((2, 2)), alpha=.7)

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])

plt.show()

# %%
x = df[['Land Area (Km²)', 'Density (P/Km²)', 'Net Change']]

# %%
# Target
y = df[['Population (2020)']]

# %%
# TTS lets us split our data into easily processed chunks
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2, random_state=6)

# %%
#Fit the model
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
print("MAE: {}".format(np.abs(y_test-y_pred).mean()))
print("RMSE: {}".format(np.sqrt(((y_test-y_pred)**2).mean())))
# Out:
# MAE: Population (2020)    4.009695e+07
# dtype: float64
# RMSE: Population (2020)    8.032200e+07
# dtype: float64

# %%
#Plotting the figure
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
#plt.clf()

#elev = 43.5
#azim = -110

ax = fig.add_subplot(projection='3d')

x = x_train[['Land Area (Km²)']]
y = x_train[['Density (P/Km²)']]
z = x_train[['Net Change']]
c = y_train

ax.set_xlabel('Land Area (Km²)')
ax.set_ylabel('Density (P/Km²)')
ax.set_zlabel('Net Change')

#Scatter Plot
img = ax.scatter(x, y, z, c=c, cmap=plt.hot())
#ax.plot_surface(np.array([[0, 0], [16376870, 16376870]]), np.array([[0, 26337], [0, 26337]]), model.predict(np.array([[0, 0, 16376870, 16376870], [0, 26337, 0, 26337]]).T).reshape((2, 2)), alpha=.7)

cbar = fig.colorbar(img)
cbar.set_label('Population')



plt.show()
